# %% [markdown]
# # This Jupyter Notebook cleans and processes the raw data from the journal article *A deep learning dataset for metal multiaxial fatigue life prediction* [2024].

# %% [markdown]
# ## First, we combine all of the linear and torsional strain data

# %% [markdown]
# Three raw data files are uploaded to a google drive. They are the "Specific information of the materials" file, the "data_all_strain-controlled" file, and a zipped file version of the "All data_Strain" folder. These files/folders were uploaded by the authors of the paper above, and can be accessed from the paper.

# %%
#First, we have to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# First, we download the files uploaded to the following google drive folder, keeping the name. https://drive.google.com/drive/folders/1snslfpCeNJcaQOKeNlvnKzsCnp2b1B66?usp=drive_link

# %% [markdown]
# Now, we load and unzip the strain data

# %%
# !find /content/drive/ -name "All_data_Strain.zip"
# Out:
# /content/drive/MyDrive/MANE4962_FinalProject_RawData/All_data_Strain.zip
# /content/drive/MyDrive/MLE_S25_Project/All_data_Strain.zip

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/MANE4962_FinalProject_RawData/All_data_Strain.zip"

extract_path = "/content/All_data_Strain"


with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import pandas as pd
import glob
import os

#Repeated name because we need to access the files in the unzipped folder
folder_path = "/content/All_data_Strain/All_data_Strain"

csv_files = glob.glob(folder_path + "/*.csv")

data_list = []

for file in csv_files:
    #Read CSV raw data
    df = pd.read_csv(file, header=None, usecols=[0, 1])
    #Reshape from array to vector
    df = df.to_numpy().flatten('F')
    #Turn back to DataFrame
    df = pd.DataFrame([df])
    #Keep original filename for tracking
    df.insert(0, "filename", os.path.basename(file))

    data_list.append(df)

# %% [markdown]
# Now, we combine our dataframes into df_strain, that contains all of the time series strain data

# %%
#Combining all strain data together
df_strain = pd.concat(data_list, ignore_index=True)

#Renaming columns manually
df_strain.columns = ["filename"] + [f"linear_strain_t{i}" for i in range(1, 242)] + [f"torsional_strain_t{i-241}" for i in range(242, 483)]

print("dataframe shape =",df_strain.shape)

df_strain.head()
# Out:
# dataframe shape = (914, 483)
#                       filename  linear_strain_t1  linear_strain_t2  \
# 0             HRB335-0.002.csv               0.0          0.000033
# 1   S460N-b-0.00104-0.0018.csv               0.0          0.000027
# 2       E235-0.0021-0.0037.csv               0.0          0.000055
# 3   E355-2-8-0.0037-0.0063.csv               0.0          0.000097
# 4  Haynes188-760-A-0.00416.csv               0.0          0.000069
#
#    linear_strain_t3  linear_strain_t4  linear_strain_t5  linear_strain_t6  \
# 0          0.000067          0.000100          0.000133          0.000167
# 1          0.000054          0.000082          0.000109          0.000136
# 2          0.000110          0.000165          0.000220          0.000274
# 3          0.000194          0.000290          0.000387          0.000483
# 4          0.000139          0.000208          0.000277          0.000347
#
#    linear_strain_t7  linear_strain_t8  linear_strain_t9  ...  \
# 0          0.000200          0.000233          0.000267  ...
# 1          0.000163          0.000190          0.000216  ...
# 2          0.000329          0.000383          0.000437  ...
# 3          0.000579          0.000674          0.000769  ...
# 4          0.000416          0.000485          0.000555  ...
#
#    torsional_strain_t232  torsional_strain_t233  torsional_strain_t234  \
# 0               0.000000               0.000000               0.000000
# 1               0.001750               0.001761               0.001770
# 2              -0.000864              -0.000769              -0.000674
# 3              -0.005097              -0.004682              -0.004216
# 4               0.000000               0.000000               0.000000
#
#    torsional_strain_t235  torsional_strain_t236  torsional_strain_t237  \
# 0               0.000000               0.000000               0.000000
# 1               0.001778               0.001785               0.001790
# 2              -0.000579              -0.000483              -0.000387
# 3              -0.003703              -0.003150              -0.002562
# 4               0.000000               0.000000               0.000000
#
#    torsional_strain_t238  torsional_strain_t239  torsional_strain_t240  \
# 0               0.000000               0.000000               0.000000
# 1               0.001794               0.001798               0.001799
# 2              -0.000290              -0.000194              -0.000097
# 3              -0.001947              -0.001310              -0.000659
# 4               0.000000               0.000000               0.000000
#
#    torsional_strain_t241
# 0                 0.0000
# 1                 0.0018
# 2                 0.0000
# 3                 0.0000
# 4                 0.0000
#
# [5 rows x 483 columns]

# %% [markdown]
# ## Second, we add the material properties to our strain data frame

# %%
csv_path = "/content/drive/MyDrive/MANE4962_FinalProject_RawData/data_all_strain-controlled.csv"
df_material_prop = pd.read_csv(csv_path)

print("dataframe shape =",df_material_prop.shape)

df_material_prop.head()
# Out:
# dataframe shape = (914, 6)
#                     load  Elastic Modulus [GPA]  \
# 0  1Cr18Ni9T-1-0.002.csv                  193.0
# 1  1Cr18Ni9T-1-0.003.csv                  193.0
# 2  1Cr18Ni9T-1-0.004.csv                  193.0
# 3  1Cr18Ni9T-1-0.005.csv                  193.0
# 4   1Cr18Ni9T-1-0.01.csv                  193.0
#
#    Ultimate Tensile Strength [MPA]  Yield Strength [MPA]  Poissons Ratio  \
# 0                            605.0                 310.0             0.3
# 1                            605.0                 310.0             0.3
# 2                            605.0                 310.0             0.3
# 3                            605.0                 310.0             0.3
# 4                            605.0                 310.0             0.3
#
#    Nf(label)
# 0   5.301030
# 1   4.093772
# 2   3.740363
# 3   3.491362
# 4   2.977724

# %% [markdown]
# Now, we will rearrange and match the indicies of df_strain and df_material_prop. This will allow the data to appended correctly

# %%
df_strain = df_strain.set_index(df_strain.iloc[:,0])
df_strain = df_strain.drop(df_strain.columns[0], axis=1)

df_material_prop = df_material_prop.set_index(df_material_prop.iloc[:,0])
df_material_prop = df_material_prop.drop(df_material_prop.columns[0], axis=1)

df_material_prop_new_index = df_material_prop.reindex(df_strain.index)

df_strain_material_target = pd.concat([df_strain, df_material_prop_new_index], axis=1)

print("dataframe shape =",df_strain_material_target.shape)

df_strain_material_target.head()
# Out:
# dataframe shape = (914, 487)
#                              linear_strain_t1  linear_strain_t2  \
# filename
# HRB335-0.002.csv                          0.0          0.000033
# S460N-b-0.00104-0.0018.csv                0.0          0.000027
# E235-0.0021-0.0037.csv                    0.0          0.000055
# E355-2-8-0.0037-0.0063.csv                0.0          0.000097
# Haynes188-760-A-0.00416.csv               0.0          0.000069
#
#                              linear_strain_t3  linear_strain_t4  \
# filename
# HRB335-0.002.csv                     0.000067          0.000100
# S460N-b-0.00104-0.0018.csv           0.000054          0.000082
# E235-0.0021-0.0037.csv               0.000110          0.000165
# E355-2-8-0.0037-0.0063.csv           0.000194          0.000290
# Haynes188-760-A-0.00416.csv          0.000139          0.000208
#
#                              linear_strain_t5  linear_strain_t6  \
# filename
# HRB335-0.002.csv                     0.000133          0.000167
# S460N-b-0.00104-0.0018.csv           0.000109          0.000136
# E235-0.0021-0.0037.csv               0.000220          0.000274
# E355-2-8-0.0037-0.0063.csv           0.000387          0.000483
# Haynes188-760-A-0.00416.csv          0.000277          0.000347
#
#                              linear_strain_t7  linear_strain_t8  \
# filename
# HRB335-0.002.csv                     0.000200          0.000233
# S460N-b-0.00104-0.0018.csv           0.000163          0.000190
# E235-0.0021-0.0037.csv               0.000329          0.000383
# E355-2-8-0.0037-0.0063.csv           0.000579          0.000674
# Haynes188-760-A-0.00416.csv          0.000416          0.000485
#
#                              linear_strain_t9  linear_strain_t10  ...  \
# filename                                                          ...
# HRB335-0.002.csv                     0.000267           0.000300  ...
# S460N-b-0.00104-0.0018.csv           0.000216           0.000243  ...
# E235-0.0021-0.0037.csv               0.000437           0.000490  ...
# E355-2-8-0.0037-0.0063.csv           0.000769           0.000864  ...
# Haynes188-760-A-0.00416.csv          0.000555           0.000624  ...
#
#                              torsional_strain_t237  torsional_strain_t238  \
# filename
# HRB335-0.002.csv                          0.000000               0.000000
# S460N-b-0.00104-0.0018.csv                0.001790               0.001794
# E235-0.0021-0.0037.csv                   -0.000387              -0.000290
# E355-2-8-0.0037-0.0063.csv               -0.002562              -0.001947
# Haynes188-760-A-0.00416.csv               0.000000               0.000000
#
#                              torsional_strain_t239  torsional_strain_t240  \
# filename
# HRB335-0.002.csv                          0.000000               0.000000
# S460N-b-0.00104-0.0018.csv                0.001798               0.001799
# E235-0.0021-0.0037.csv                   -0.000194              -0.000097
# E355-2-8-0.0037-0.0063.csv               -0.001310              -0.000659
# Haynes188-760-A-0.00416.csv               0.000000               0.000000
#
#                              torsional_strain_t241  Elastic Modulus [GPA]  \
# filename
# HRB335-0.002.csv                            0.0000              210.00000
# S460N-b-0.00104-0.0018.csv                  0.0018              208.50000
# E235-0.0021-0.0037.csv                      0.0000              196.40000
# E355-2-8-0.0037-0.0063.csv                  0.0000              208.60000
# Haynes188-760-A-0.00416.csv                 0.0000              146.93456
#
#                              Ultimate Tensile Strength [MPA]  \
# filename
# HRB335-0.002.csv                                       520.0
# S460N-b-0.00104-0.0018.csv                             643.0
# E235-0.0021-0.0037.csv                                 375.4
# E355-2-8-0.0037-0.0063.csv                             473.0
# Haynes188-760-A-0.00416.csv                            490.0
#
#                              Yield Strength [MPA]  Poissons Ratio  Nf(label)
# filename
# HRB335-0.002.csv                            355.0            0.30   4.482044
# S460N-b-0.00104-0.0018.csv                  500.0            0.30   5.759366
# E235-0.0021-0.0037.csv                      247.8            0.30   4.254500
# E355-2-8-0.0037-0.0063.csv                  318.4            0.29   2.985875
# Haynes188-760-A-0.00416.csv                 268.0            0.50   4.545381
#
# [5 rows x 487 columns]

# %% [markdown]
# ## Finally, the material type is added to our dataframe

# %% [markdown]
# First, we import the raw data excel sheet for the material breakdowns

# %%
xlsx_path = "/content/drive/MyDrive/MANE4962_FinalProject_RawData/Specific information of the materials.xlsx"
df_materials = pd.read_excel(xlsx_path)
df_materials.head()
# Out:
#           Category             Material  \
# 0  Stainless Steel          1Cr–18Ni–9T
# 1              NaN                 S347
# 2              NaN          X5CrNi18-10
# 3              NaN            AISI 316L
# 4              NaN  304 stainless steel
#
#                    Chemical Constituents in Weight %  \
# 0  C (0.065); Mn (1.34); Si (0.95); S (0.03); P (...
# 1  C < 0.08; Mn < 2; Si < 1; P < 0.045; S < 0.03;...
# 2                                      Not specified
# 3                                      Not specified
# 4  Cr (19.2); Ni (10.8); Mn (1.6); Si (0.40); P<0...
#
#       Additional processing information of specimens      Specimen type  \
# 0             The base material is solution-treated.  Tubular specimens
# 1  The specimens were rolled after drilling but b...  Tubular specimens
# 2         Austenitic stainless steel, soft annealed.  Tubular specimens
# 3                                     Not specified.  Tubular specimens
# 4  Specimen surfaces were polished to a 0.3 micro...  Tubular specimens
#
#                                         Test machine Loading frequency  \
# 0                                     Instron 8800       Not specified
# 1                    A servohydraulic loading device              2 Hz
# 2                                       Instron 8874        0.1 - 2 Hz
# 3                                      MTS Model 809            0.1 Hz
# 4  A two post axial servo-hydraulic test frame wi...     Not specified
#
#                           Loading paths     Loading method  Samples  \
# 0                            U1, U2, S1  Strain controlled       14
# 1                    U1, U2, P1, S1, S3  Strain controlled       19
# 2  U1,U2,P1,S1,SF12,SF13,SF15,SF16,SF19  Strain controlled       63
# 3                        U1,U2,P1,S1,S3  Strain controlled       25
# 4                     U1,U2,P1,S1,B1,B2  Strain controlled        8
#
#                                                  Ref
# 0  Chen, X., An, K., & Kim, K. S. (2004). Low‐cyc...
# 1  Hoffmeyer, J., Döring, R., Seeger, T., & Vormw...
# 2  Pejkowski, Ł., & Skibicki, D. (2019). Stress-s...
# 3  Feng, E. S., Wang, X. G., & Jiang, C. (2019). ...
# 4  Jones, D., & Kurath, P. (1988). Cyclic Fatigue...

# %% [markdown]
# We need to change the NaN values to the first NaN value that comes before it

# %%
for i in range(len(df_materials)): #Iterates through 41 different allows
  if pd.isna(df_materials.loc[i, 'Category']): #Following line runs only if NaN value is detected
    df_materials.loc[i, 'Category'] = df_materials.loc[i-1, 'Category'] #Pulls value from previous row

df_materials.head()
# Out:
#           Category             Material  \
# 0  Stainless Steel          1Cr–18Ni–9T
# 1  Stainless Steel                 S347
# 2  Stainless Steel          X5CrNi18-10
# 3  Stainless Steel            AISI 316L
# 4  Stainless Steel  304 stainless steel
#
#                    Chemical Constituents in Weight %  \
# 0  C (0.065); Mn (1.34); Si (0.95); S (0.03); P (...
# 1  C < 0.08; Mn < 2; Si < 1; P < 0.045; S < 0.03;...
# 2                                      Not specified
# 3                                      Not specified
# 4  Cr (19.2); Ni (10.8); Mn (1.6); Si (0.40); P<0...
#
#       Additional processing information of specimens      Specimen type  \
# 0             The base material is solution-treated.  Tubular specimens
# 1  The specimens were rolled after drilling but b...  Tubular specimens
# 2         Austenitic stainless steel, soft annealed.  Tubular specimens
# 3                                     Not specified.  Tubular specimens
# 4  Specimen surfaces were polished to a 0.3 micro...  Tubular specimens
#
#                                         Test machine Loading frequency  \
# 0                                     Instron 8800       Not specified
# 1                    A servohydraulic loading device              2 Hz
# 2                                       Instron 8874        0.1 - 2 Hz
# 3                                      MTS Model 809            0.1 Hz
# 4  A two post axial servo-hydraulic test frame wi...     Not specified
#
#                           Loading paths     Loading method  Samples  \
# 0                            U1, U2, S1  Strain controlled       14
# 1                    U1, U2, P1, S1, S3  Strain controlled       19
# 2  U1,U2,P1,S1,SF12,SF13,SF15,SF16,SF19  Strain controlled       63
# 3                        U1,U2,P1,S1,S3  Strain controlled       25
# 4                     U1,U2,P1,S1,B1,B2  Strain controlled        8
#
#                                                  Ref
# 0  Chen, X., An, K., & Kim, K. S. (2004). Low‐cyc...
# 1  Hoffmeyer, J., Döring, R., Seeger, T., & Vormw...
# 2  Pejkowski, Ł., & Skibicki, D. (2019). Stress-s...
# 3  Feng, E. S., Wang, X. G., & Jiang, C. (2019). ...
# 4  Jones, D., & Kurath, P. (1988). Cyclic Fatigue...

# %% [markdown]
# Now, we rearrange and match the indicies like before, to add this material data onto our strain_material_target dataframe

# %%
#First, we make a dictionary from our material dataframe
material_category_map = df_materials.set_index('Material')['Category'].to_dict()

def append_material(index):
    #Make sure index is a string
    index_str = str(index)

    for material in material_category_map:
        #Make sure variable we loop through is also a string
        #Check if material name is present in index
        if str(material) in index_str:
            return material_category_map[material]
    return None

#Use the function on our dataframe to add the new material column
df_strain_material_target['Material'] = df_strain_material_target.index.map(append_material)

df_strain_material_target.head()
# Out:
#                              linear_strain_t1  linear_strain_t2  \
# filename
# HRB335-0.002.csv                          0.0          0.000033
# S460N-b-0.00104-0.0018.csv                0.0          0.000027
# E235-0.0021-0.0037.csv                    0.0          0.000055
# E355-2-8-0.0037-0.0063.csv                0.0          0.000097
# Haynes188-760-A-0.00416.csv               0.0          0.000069
#
#                              linear_strain_t3  linear_strain_t4  \
# filename
# HRB335-0.002.csv                     0.000067          0.000100
# S460N-b-0.00104-0.0018.csv           0.000054          0.000082
# E235-0.0021-0.0037.csv               0.000110          0.000165
# E355-2-8-0.0037-0.0063.csv           0.000194          0.000290
# Haynes188-760-A-0.00416.csv          0.000139          0.000208
#
#                              linear_strain_t5  linear_strain_t6  \
# filename
# HRB335-0.002.csv                     0.000133          0.000167
# S460N-b-0.00104-0.0018.csv           0.000109          0.000136
# E235-0.0021-0.0037.csv               0.000220          0.000274
# E355-2-8-0.0037-0.0063.csv           0.000387          0.000483
# Haynes188-760-A-0.00416.csv          0.000277          0.000347
#
#                              linear_strain_t7  linear_strain_t8  \
# filename
# HRB335-0.002.csv                     0.000200          0.000233
# S460N-b-0.00104-0.0018.csv           0.000163          0.000190
# E235-0.0021-0.0037.csv               0.000329          0.000383
# E355-2-8-0.0037-0.0063.csv           0.000579          0.000674
# Haynes188-760-A-0.00416.csv          0.000416          0.000485
#
#                              linear_strain_t9  linear_strain_t10  ...  \
# filename                                                          ...
# HRB335-0.002.csv                     0.000267           0.000300  ...
# S460N-b-0.00104-0.0018.csv           0.000216           0.000243  ...
# E235-0.0021-0.0037.csv               0.000437           0.000490  ...
# E355-2-8-0.0037-0.0063.csv           0.000769           0.000864  ...
# Haynes188-760-A-0.00416.csv          0.000555           0.000624  ...
#
#                              torsional_strain_t238  torsional_strain_t239  \
# filename
# HRB335-0.002.csv                          0.000000               0.000000
# S460N-b-0.00104-0.0018.csv                0.001794               0.001798
# E235-0.0021-0.0037.csv                   -0.000290              -0.000194
# E355-2-8-0.0037-0.0063.csv               -0.001947              -0.001310
# Haynes188-760-A-0.00416.csv               0.000000               0.000000
#
#                              torsional_strain_t240  torsional_strain_t241  \
# filename
# HRB335-0.002.csv                          0.000000                 0.0000
# S460N-b-0.00104-0.0018.csv                0.001799                 0.0018
# E235-0.0021-0.0037.csv                   -0.000097                 0.0000
# E355-2-8-0.0037-0.0063.csv               -0.000659                 0.0000
# Haynes188-760-A-0.00416.csv               0.000000                 0.0000
#
#                              Elastic Modulus [GPA]  \
# filename
# HRB335-0.002.csv                         210.00000
# S460N-b-0.00104-0.0018.csv               208.50000
# E235-0.0021-0.0037.csv                   196.40000
# E355-2-8-0.0037-0.0063.csv               208.60000
# Haynes188-760-A-0.00416.csv              146.93456
#
#                              Ultimate Tensile Strength [MPA]  \
# filename
# HRB335-0.002.csv                                       520.0
# S460N-b-0.00104-0.0018.csv                             643.0
# E235-0.0021-0.0037.csv                                 375.4
# E355-2-8-0.0037-0.0063.csv                             473.0
# Haynes188-760-A-0.00416.csv                            490.0
#
#                              Yield Strength [MPA]  Poissons Ratio  Nf(label)  \
# filename
# HRB335-0.002.csv                            355.0            0.30   4.482044
# S460N-b-0.00104-0.0018.csv                  500.0            0.30   5.759366
# E235-0.0021-0.0037.csv                      247.8            0.30   4.254500
# E355-2-8-0.0037-0.0063.csv                  318.4            0.29   2.985875
# Haynes188-760-A-0.00416.csv                 268.0            0.50   4.545381
#
#                                            Material
# filename
# HRB335-0.002.csv             Carbon and Alloy Steel
# S460N-b-0.00104-0.0018.csv   Carbon and Alloy Steel
# E235-0.0021-0.0037.csv       Carbon and Alloy Steel
# E355-2-8-0.0037-0.0063.csv   Carbon and Alloy Steel
# Haynes188-760-A-0.00416.csv                    None
#
# [5 rows x 488 columns]

# %% [markdown]
# We now need to swap the last two columns, so our target data [Nf], is the last column in our dataframe

# %%
column_names = list(df_strain_material_target.columns)
last_two_columns = column_names[-2:]
other_columns = column_names[:-2]
swapped_columns = other_columns + [last_two_columns[1], last_two_columns[0]]

df_final = df_strain_material_target[swapped_columns]

df_final.head()
# Out:
#                              linear_strain_t1  linear_strain_t2  \
# filename
# HRB335-0.002.csv                          0.0          0.000033
# S460N-b-0.00104-0.0018.csv                0.0          0.000027
# E235-0.0021-0.0037.csv                    0.0          0.000055
# E355-2-8-0.0037-0.0063.csv                0.0          0.000097
# Haynes188-760-A-0.00416.csv               0.0          0.000069
#
#                              linear_strain_t3  linear_strain_t4  \
# filename
# HRB335-0.002.csv                     0.000067          0.000100
# S460N-b-0.00104-0.0018.csv           0.000054          0.000082
# E235-0.0021-0.0037.csv               0.000110          0.000165
# E355-2-8-0.0037-0.0063.csv           0.000194          0.000290
# Haynes188-760-A-0.00416.csv          0.000139          0.000208
#
#                              linear_strain_t5  linear_strain_t6  \
# filename
# HRB335-0.002.csv                     0.000133          0.000167
# S460N-b-0.00104-0.0018.csv           0.000109          0.000136
# E235-0.0021-0.0037.csv               0.000220          0.000274
# E355-2-8-0.0037-0.0063.csv           0.000387          0.000483
# Haynes188-760-A-0.00416.csv          0.000277          0.000347
#
#                              linear_strain_t7  linear_strain_t8  \
# filename
# HRB335-0.002.csv                     0.000200          0.000233
# S460N-b-0.00104-0.0018.csv           0.000163          0.000190
# E235-0.0021-0.0037.csv               0.000329          0.000383
# E355-2-8-0.0037-0.0063.csv           0.000579          0.000674
# Haynes188-760-A-0.00416.csv          0.000416          0.000485
#
#                              linear_strain_t9  linear_strain_t10  ...  \
# filename                                                          ...
# HRB335-0.002.csv                     0.000267           0.000300  ...
# S460N-b-0.00104-0.0018.csv           0.000216           0.000243  ...
# E235-0.0021-0.0037.csv               0.000437           0.000490  ...
# E355-2-8-0.0037-0.0063.csv           0.000769           0.000864  ...
# Haynes188-760-A-0.00416.csv          0.000555           0.000624  ...
#
#                              torsional_strain_t238  torsional_strain_t239  \
# filename
# HRB335-0.002.csv                          0.000000               0.000000
# S460N-b-0.00104-0.0018.csv                0.001794               0.001798
# E235-0.0021-0.0037.csv                   -0.000290              -0.000194
# E355-2-8-0.0037-0.0063.csv               -0.001947              -0.001310
# Haynes188-760-A-0.00416.csv               0.000000               0.000000
#
#                              torsional_strain_t240  torsional_strain_t241  \
# filename
# HRB335-0.002.csv                          0.000000                 0.0000
# S460N-b-0.00104-0.0018.csv                0.001799                 0.0018
# E235-0.0021-0.0037.csv                   -0.000097                 0.0000
# E355-2-8-0.0037-0.0063.csv               -0.000659                 0.0000
# Haynes188-760-A-0.00416.csv               0.000000                 0.0000
#
#                              Elastic Modulus [GPA]  \
# filename
# HRB335-0.002.csv                         210.00000
# S460N-b-0.00104-0.0018.csv               208.50000
# E235-0.0021-0.0037.csv                   196.40000
# E355-2-8-0.0037-0.0063.csv               208.60000
# Haynes188-760-A-0.00416.csv              146.93456
#
#                              Ultimate Tensile Strength [MPA]  \
# filename
# HRB335-0.002.csv                                       520.0
# S460N-b-0.00104-0.0018.csv                             643.0
# E235-0.0021-0.0037.csv                                 375.4
# E355-2-8-0.0037-0.0063.csv                             473.0
# Haynes188-760-A-0.00416.csv                            490.0
#
#                              Yield Strength [MPA]  Poissons Ratio  \
# filename
# HRB335-0.002.csv                            355.0            0.30
# S460N-b-0.00104-0.0018.csv                  500.0            0.30
# E235-0.0021-0.0037.csv                      247.8            0.30
# E355-2-8-0.0037-0.0063.csv                  318.4            0.29
# Haynes188-760-A-0.00416.csv                 268.0            0.50
#
#                                            Material  Nf(label)
# filename
# HRB335-0.002.csv             Carbon and Alloy Steel   4.482044
# S460N-b-0.00104-0.0018.csv   Carbon and Alloy Steel   5.759366
# E235-0.0021-0.0037.csv       Carbon and Alloy Steel   4.254500
# E355-2-8-0.0037-0.0063.csv   Carbon and Alloy Steel   2.985875
# Haynes188-760-A-0.00416.csv                    None   4.545381
#
# [5 rows x 488 columns]

# %% [markdown]
# Now, we upload this data frame into the same google drive folder for use in training future ML models

# %%
df_final.to_csv('/content/drive/MyDrive/MANE4962_FinalProject_RawData/final_data.csv', index=True)
